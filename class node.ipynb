# %%
class Node:
    def __init__ (self,data):
        self.data = data
        self.next = None
def length(head):
    count=0
    while head is not None:
        count=count+1
        head=head.next
    return count
    
def inode(head,i,data):
    newNode=Node(data)
    if i<0  or i>length(head):
        return head
    count = 0
    prev=None
    curr = head
    while count<i:
        prev=curr
        curr=curr.next
        count=count+1
        
    newNode=Node(data)
    if prev is not None:
        prev.next = newNode
    else :
        head = newNode
    newNode.next = curr
    return head
    
def printll(head):
    while head is not None:
        print(str(head.data), end = " ")
        head = head.next
    print()
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail = None
    for currData in inputlist:
        if currData == -1:
            break
        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return  head 
head = takeinput()
printll(head)
head = inode(head,2,6)
printll(head)
head = inode(head,0,9)
printll(head)
head = inode(head,7,19)
printll(head)
# Out:
# 1 2 3 5 4 -1
# 1 2 3 5 4
# 1 2 6 3 5 4
# 9 1 2 6 3 5 4
# 9 1 2 6 3 5 4 19

# %%
##insertion using recursion
class node:
    def __init__ (self,data):
        self.data = data
        self.next = None
def printll(head):
    while head is not None:
        print (str(head.data),end=" ")
        head = head.next
    print()

def length(head):
    count=0
    while head is not None:
        count=count+1
        head=head.next
    return count

def InsertatIR(head,i,data):  ##assuming index is starting from zero
    if i<0:
        return head
    if i ==0: 
        newnode=Node(data)
        newnode.next=head
        return newnode ##need to return the new_head
    if head is None: ##this is below i==0,so that link can be made @last position easily
        return None
    small_head=InsertatIR(head.next,i-1,data)
    head.next = small_head ##maintaining the link with the prev head
    return head
def takinginput():
    inputlist =[int(ele) for ele in input().split()]
    head = None
    tail = None
    for currData in inputlist:
        if currdata==-1:
            break
        newnode=Node(currdata)
        if head is None:
            head=newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
    return head
head=takeinput()
printll(head)
head=InsertatIR(head,0,7)
printll(head)
head=InsertatIR(head,1,8)
printll(head)
head=InsertatIR(head,7,5)
printll(head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-39c0a846586f> in <module>
#      44             tail=newnode
#      45     return head
# ---> 46 head=takeinput()
#      47 printll(head)
#      48 head=InsertatIR(head,0,7)
#
# NameError: name 'takeinput' is not defined

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
def valueati(head,i):
    temp=head
    count = 0
    while (temp is not None) and count<i:  ##we cant take temp.next != -1 since temp ka data h -1
        temp=temp.next 
        count=count+1
        if count==i:
            print (temp.data)
def takeinput():
    inputlist = [int(ele) for ele in input().split()]
    head = None
    tail = None
    for currData in inputlist:
        if currData==-1:
            break
        newNode = Node (currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return head 
def printll(head):
    while head is not None:
        print(str(head.data), end = " ")
        head = head.next 
    print()

head = takeinput()
printll(head)
head=valueati(head,0)
# Out:
# 1 3 5 7 -1
# 1 3 5 7

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
def length(head):
    count=0
    while head is not None:
        count=count+1
        head=head.next
    return count

def deletenode(head,i):
    if i>=length(head):
        return head
    count = 0
    prev=None
    curr=head
    while count<i:
        prev=curr
        curr=curr.next
        count+=1
    if prev is not None:
        if pos ==length(head):
            prev.next=curr
        else:
            prev.next=curr.next
    else:
        head=head.next
    del curr  
    return head 
def takeinput ():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail =  None
    for currData in inputlist:
        if currData == -1:
            break
        newnode = Node(currData)
        if head is None:
            head=newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
    return head 
def printll(head):
    while head is not None:
        print(str(head.data),end=" ")
        head = head.next
    print()
    return head 
head = takeinput()
printll(head)
head=deletenode(head,4)
printll(head)
# Out:
# 13 4 5 7 -1
# 13 4 5 7
# 13 4 5 7

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
def takeinput():
    inputlist = [int(ele) for ele in input().split()]
    head = None
    tail = None
    for currData in inputlist:
        if currData == -1:
            break
        newnode=Node(currData)
        if head is None:
            head = newnode
            tail = newnode
        else:
            tail.next=newnode
            tail=newnode
        return head
def printll(head):
    while head is not None:
        print(head.data, end=" ")
        head = head.next
    print()
def deletenIR (head,i):
