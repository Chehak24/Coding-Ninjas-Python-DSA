# %%
##delete node recursively


class Node:
    def __init__ (self,data):
        self.data = data
        self.next = None
        
def lengthR(head):
    if head is None:
        return 0
    return 1+lengthR(head.next)
        
def printll(head):
    while head is not None:
        print (head.data, end=" ")
        head=head.next
    print()
    
def deletenodeir(head,i):
    temp = head
    if i<0 or i==lengthR(head):
        return head
    if i == 0:
        head=temp.next
        del temp 
    if head is None:
        return head
    smalldel=deletenodeir(head.next,i-1)
    head.next=smalldel
    return head
def takeinput():
    inputlist = [int(ele) for ele in input().split()]
    head = None
    tail = None
    for currdata in inputlist:
        if currdata == -1:
            break
        newnode = Node(currdata)
        if head is None:
            head = newnode
            tail = newnode
        else:
            tail.next=newnode
            tail=newnode
    return head 
head = takeinput()
printll(head)
head = deletenodeir(head,7)
printll(head)
# Out:
# 11 4 6 8 7 -1
# 11 4 6 8 7
# 11 4 6 8 7

# %%
##insert at I recursively

class node:
    def __init__ (self,data):
        self.data = data
        self.next = None
def printll(head):
    while head is not None:
        print (head.data,end=" ")
        head = head.next
    print()


def InsertatIR(head,i,data):  ##assuming index is starting from zero
    if i<0:
        return head
    if i ==0: 
        newnode=Node(data)
        newnode.next=head
        return newnode ##need to return the new_head
    if head is None: ##this is below i==0,so that link can be made @last position easily
        return None
    small_head=InsertatIR(head.next,i-1,data)
    head.next = small_head ##maintaining the link with the prev head
    return head
def takinginput():
    inputlist =[int(ele) for ele in input().split()]
    head = None
    tail = None
    for currData in inputlist:
        if currData==-1:
            break
        newnode=Node(currData)
        if head is None:
            head=newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
    return head
head=takinginput()
printll(head)
head=InsertatIR(head,0,7)
printll(head)
head=InsertatIR(head,1,8)
printll(head)
head=InsertatIR(head,7,5)
printll(head)
# Out:
# 1 3 5 7 9 -1
# 1 3 5 7 9
# 7 1 3 5 7 9
# 7 8 1 3 5 7 9
# 7 8 1 3 5 7 9 5

# %%
##rough 

def length(head):
    count=0
    while head is not None:
        count=count+1
        head=head.next
    return count



def deletenodeir(head,i):
    temp = head
    if i<0:
        return head
    if head is None:
        return None
    if i == 0:
        temp=temp.next
        del temp
    smalldel=deletenodeir(head.next,i-1)
    head.next=smalldel
    return hea

# %%
##find node

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
def printll(head):
    while head is not None:
        print(head.data,end=" ")
        head=head.next
    print()

def findnode(head,n):
    curr=head
    count=0
    while curr is not None:
        if curr.data == n:
            return count
        count=count+1
        curr=curr.next
    return -1
        
def takinginput():
    inputlist = [int (ele) for ele in input().split()]
    head = None
    tail = None
    for currdata in inputlist:
        if currdata== -1:
            break
        newnode = Node(currdata)
        if  head is None:
            head=newnode
            tail=newnode
        else:
            tail.next = newnode
            tail = newnode
    return head
head=takinginput()
printll(head)
head=findnode(head,0)
print(head)
# Out:
# -1
#
# -1

# %%
##rotate at n fail
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
def printll(head):
    while head is not None:
        print(head.data,end=" ")
        head=head.next
    print()

def length(head):
    count=0
    while head is not None:
        count=count+1
        head=head.next
    return count

def rotateatn(head,n):
    curr=head
    i=1
    pos=length(head)-n
    while i<pos:
        curr=curr.next
        i=i+1
    temp=curr.next
    while temp is not None:
        temp=temp.next
    temp=head
def takeinput():
    inputlist = [int(ele) for ele in input().split()]
    head= None
    tail = None
    for currdata in inputlist:
        if currdata==-1:
            break
        newnode=Node(currdata)
        if head is None:
            head= newnode
            tail = newnode
        else:
            tail.next=newnode
            tail = newnode
    return head 
head= takeinput()
printll(head)
head=rotateatn(head,3)
printll(head)
# Out:
# 1 3 5 7 9 6 -1
# 1 3 5 7 9 6

# %%
##check palindrome fail
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def printll(head):
    while head is not None:
        print(head.data,end=" ")
        head=head.next
    print()
    
def length(head):
    count = 0
    while head is not None:
        count=count+1
        head=head.next
    return count
def palindrome:
    mid=length//2
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail = None
    for currdata in inputlist:
        if currdata == -1:
            break
        newnode=Node(currdata)
        if head is None:
            head=newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
    return head 

head=takeinput()
printll(head)
head=length(head)
# Out:
# 1 3 5 7 9 -1
# 1 3 5 7 9
# 5

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
def printll(head):
    while head is not None:
        print(head.data,end=" ")
        head=head.next
    print()
def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail = None
    for currdata in inputlist:
        if currdata == -1:
            break
        newnode=Node(currdata)
        if head is None:
            head=newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
    return head 
def length(head):
    return len(inputlist)

head=takeinput()
printll(head)
head=length(head)
# Out:
# 1 3 5 7 9 -1
# 1 3 5 7 9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8cb1ea83b56b> in <module>
#      28 head=takeinput()
#      29 printll(head)
# ---> 30 head=length(head)
#
# <ipython-input-2-8cb1ea83b56b> in length(head)
#      24     return head
#      25 def length(head):
# ---> 26     return len(inputlist)
#      27
#      28 head=takeinput()
#
# NameError: name 'inputlist' is not defined

# %%
##checkpalindrome 

class Node:
    def __init__(self,data):
        self.data=data
        self.next = None
        
def printll(head):
    list=[]
    while head is not None:
        list.insert(0,head.data)
        head=head.next
    return list

def reversell(head):
    list=[]
    while head is not None:
        list.append(head.data)
        head=head.next
    return list 

def checkpalindrome(head):
    while head is not None:
        if printll(head)==reversell(head):
            head=head.next
            return True
        return False 
    return True
        

def takeinput():
    inputlist=[int(ele) for ele in input().split()]
    head = None
    tail=None
    for currdata in inputlist:
        if currdata == -1:
            break
        newnode=Node(currdata)
        if head is None:
            head=newnode
            tail=newnode
        else:
            tail.next=newnode
            tail=newnode
    return head

head=takeinput()
ans=checkpalindrome(head)
if ans:
    print ("true")
else:
    print("false")
# Out:
# -1 -1
# true
